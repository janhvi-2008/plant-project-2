# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("plant_dataset.csv")
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Plant_ID         500 non-null    str
#  1   Days             500 non-null    int64
#  2   Temperature_C    500 non-null    int64
#  3   Humidity_%       500 non-null    int64
#  4   Rainfall_mm      500 non-null    int64
#  5   Soil_Moisture_%  500 non-null    int64
#  6   Sunlight_hr      500 non-null    int64
#  7   Fertilizer_g     500 non-null    int64
#  8   Plant_Height_cm  500 non-null    float64
# dtypes: float64(1), int64(7), str(1)
# memory usage: 35.3 KB

# %%
df
# Out:
#     Plant_ID  Days  Temperature_C  Humidity_%  Rainfall_mm  Soil_Moisture_%  \
# 0       P001   168             21          41           23               47
# 1       P002    31             35          45           18               57
# 2       P003    64             34          78            0               65
# 3       P004   119             36          57           25               30
# 4       P005    92             26          49            6               78
# ..       ...   ...            ...         ...          ...              ...
# 495     P496   100             32          87            2               67
# 496     P497   105             20          77           18               33
# 497     P498    71             28          65           22               77
# 498     P499    64             20          52            4               79
# 499     P500    32             23          68           14               50
#
#      Sunlight_hr  Fertilizer_g  Plant_Height_cm
# ...

# %%
df.tail()
# Out:
#     Plant_ID  Days  Temperature_C  Humidity_%  Rainfall_mm  Soil_Moisture_%  \
# 495     P496   100             32          87            2               67
# 496     P497   105             20          77           18               33
# 497     P498    71             28          65           22               77
# 498     P499    64             20          52            4               79
# 499     P500    32             23          68           14               50
#
#      Sunlight_hr  Fertilizer_g  Plant_Height_cm
# 495            4            42            72.73
# 496            7            18            68.25
# 497            6            30            63.38
# 498           10            47            57.81
# 499            7            17            34.14

# %%
print("Number of Rows and Columns:")
print(df.shape)
# Out:
# Number of Rows and Columns:
# (500, 9)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Plant_ID         500 non-null    str
#  1   Days             500 non-null    int64
#  2   Temperature_C    500 non-null    int64
#  3   Humidity_%       500 non-null    int64
#  4   Rainfall_mm      500 non-null    int64
#  5   Soil_Moisture_%  500 non-null    int64
#  6   Sunlight_hr      500 non-null    int64
#  7   Fertilizer_g     500 non-null    int64
#  8   Plant_Height_cm  500 non-null    float64
# dtypes: float64(1), int64(7), str(1)
# memory usage: 35.3 KB

# %%
print(df.dtypes)
# Out:
# Plant_ID               str
# Days                 int64
# Temperature_C        int64
# Humidity_%           int64
# Rainfall_mm          int64
# Soil_Moisture_%      int64
# Sunlight_hr          int64
# Fertilizer_g         int64
# Plant_Height_cm    float64
# dtype: object

# %%
print(df.isnull().sum())
# Out:
# Plant_ID           0
# Days               0
# Temperature_C      0
# Humidity_%         0
# Rainfall_mm        0
# Soil_Moisture_%    0
# Sunlight_hr        0
# Fertilizer_g       0
# Plant_Height_cm    0
# dtype: int64

# %%
print("Duplicate Rows =", df.duplicated().sum())
# Out:
# Duplicate Rows = 0

# %%
df = df.drop_duplicates()

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.describe()
# Out:
#             Days  Temperature_C  Humidity_%  Rainfall_mm  Soil_Moisture_%  \
# count  500.00000     500.000000  500.000000   500.000000       500.000000
# mean    94.90000      28.198000   66.104000    14.642000        55.640000
# std     49.78054       5.959348   14.598473     8.875776        14.135701
# min      6.00000      18.000000   40.000000     0.000000        30.000000
# 25%     51.75000      23.000000   54.000000     7.000000        44.000000
# 50%     96.00000      28.000000   66.000000    15.000000        56.000000
# 75%    136.25000      33.250000   79.000000    22.000000        67.000000
# max    180.00000      38.000000   90.000000    30.000000        80.000000
#
#        Sunlight_hr  Fertilizer_g  Plant_Height_cm
# count   500.000000    500.000000       500.000000
# mean      7.072000     30.194000        70.511320
# std       1.934503     12.254661        27.622897
# min       4.000000     10.000000        17.480000
# ...

# %%
df.describe(include='all')
# Out:
#        Plant_ID       Days  Temperature_C  Humidity_%  Rainfall_mm  \
# count       500  500.00000     500.000000  500.000000   500.000000
# unique      500        NaN            NaN         NaN          NaN
# top        P001        NaN            NaN         NaN          NaN
# freq          1        NaN            NaN         NaN          NaN
# mean        NaN   94.90000      28.198000   66.104000    14.642000
# std         NaN   49.78054       5.959348   14.598473     8.875776
# min         NaN    6.00000      18.000000   40.000000     0.000000
# 25%         NaN   51.75000      23.000000   54.000000     7.000000
# 50%         NaN   96.00000      28.000000   66.000000    15.000000
# 75%         NaN  136.25000      33.250000   79.000000    22.000000
# max         NaN  180.00000      38.000000   90.000000    30.000000
#
#         Soil_Moisture_%  Sunlight_hr  Fertilizer_g  Plant_Height_cm
# count        500.000000   500.000000    500.000000       500.000000
# ...

# %%
print(df.columns)
# Out:
# Index(['Plant_ID', 'Days', 'Temperature_C', 'Humidity_%', 'Rainfall_mm',
#        'Soil_Moisture_%', 'Sunlight_hr', 'Fertilizer_g', 'Plant_Height_cm'],
#       dtype='str')

# %%
X = df[['Days',
        'Temperature_C',
        'Humidity_%',
        'Rainfall_mm',
        'Soil_Moisture_%',
        'Sunlight_hr',
        'Fertilizer_g']]

# %%
y = df['Plant_Height_cm']

# %%
print(X.head())
# Out:
#    Days  Temperature_C  Humidity_%  Rainfall_mm  Soil_Moisture_%  Sunlight_hr  \
# 0   168             21          41           23               47            5
# 1    31             35          45           18               57            4
# 2    64             34          78            0               65            5
# 3   119             36          57           25               30           10
# 4    92             26          49            6               78            6
#
#    Fertilizer_g
# 0            24
# 1            11
# 2            44
# 3            20
# 4            16

# %%
print(y.head())
# Out:
# 0    105.94
# 1     31.41
# 2     54.20
# 3     79.68
# 4     70.80
# Name: Plant_Height_cm, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
print("Training Data Shape")

print(X_train.shape)
print(y_train.shape)
# Out:
# Training Data Shape
# (400, 7)
# (400,)

# %%
print("Testing Data Shape")

print(X_test.shape)
print(y_test.shape)
# Out:
# Testing Data Shape
# (100, 7)
# (100,)

# %%
print(X_train.head())
# Out:
#      Days  Temperature_C  Humidity_%  Rainfall_mm  Soil_Moisture_%  \
# 249    25             18          56            6               39
# 433   120             37          43           27               52
# 19     92             21          58           13               40
# 322    17             34          54           20               44
# 332   168             30          67           16               50
#
#      Sunlight_hr  Fertilizer_g
# 249            8            48
# 433            4            41
# 19             7            10
# 322            4            16
# 332            4            35

# %%
print(X_test.head())
# Out:
#      Days  Temperature_C  Humidity_%  Rainfall_mm  Soil_Moisture_%  \
# 361   148             31          66           17               63
# 73    126             37          89            2               59
# 374   144             33          51           29               64
# 155    25             37          64           19               73
# 104   157             26          75            0               63
#
#      Sunlight_hr  Fertilizer_g
# 361            5            34
# 73             7            50
# 374            9            13
# 155            5            41
# 104            5            15

# %%
#EDA
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("plant_dataset.csv")

# %%
df.head()
# Out:
#   Plant_ID  Days  Temperature_C  Humidity_%  Rainfall_mm  Soil_Moisture_%  \
# 0     P001   168             21          41           23               47
# 1     P002    31             35          45           18               57
# 2     P003    64             34          78            0               65
# 3     P004   119             36          57           25               30
# 4     P005    92             26          49            6               78
#
#    Sunlight_hr  Fertilizer_g  Plant_Height_cm
# 0            5            24           105.94
# 1            4            11            31.41
# 2            5            44            54.20
# 3           10            20            79.68
# 4            6            16            70.80

# %%
df.tail()
# Out:
#     Plant_ID  Days  Temperature_C  Humidity_%  Rainfall_mm  Soil_Moisture_%  \
# 495     P496   100             32          87            2               67
# 496     P497   105             20          77           18               33
# 497     P498    71             28          65           22               77
# 498     P499    64             20          52            4               79
# 499     P500    32             23          68           14               50
#
#      Sunlight_hr  Fertilizer_g  Plant_Height_cm
# 495            4            42            72.73
# 496            7            18            68.25
# 497            6            30            63.38
# 498           10            47            57.81
# 499            7            17            34.14

# %%
df.hist(figsize=(15,10), bins=15)

plt.suptitle("Histogram of Plant Growth Dataset")

plt.show()

# %%
plt.figure(figsize=(7,5))

plt.hist(df['Plant_Height_cm'], bins=20)

plt.title("Distribution of Plant Height")

plt.xlabel("Plant Height (cm)")

plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(7,5))

plt.scatter(df['Days'], df['Plant_Height_cm'])

plt.title("Days vs Plant Height")

plt.xlabel("Days")

plt.ylabel("Plant Height (cm)")

plt.show()

# %%
plt.figure(figsize=(7,5))

plt.scatter(df['Temperature_C'], df['Plant_Height_cm'])

plt.title("Temperature vs Plant Height")

plt.xlabel("Temperature (°C)")

plt.ylabel("Plant Height (cm)")

plt.show()

# %%
plt.figure(figsize=(7,5))

plt.scatter(df['Humidity_%'], df['Plant_Height_cm'])

plt.title("Humidity vs Plant Height")

plt.xlabel("Humidity (%)")

plt.ylabel("Plant Height (cm)")

plt.show()

# %%
plt.figure(figsize=(7,5))

plt.scatter(df['Rainfall_mm'], df['Plant_Height_cm'])

plt.title("Rainfall vs Plant Height")

plt.xlabel("Rainfall (mm)")

plt.ylabel("Plant Height (cm)")

plt.show()

# %%
plt.figure(figsize=(7,5))

plt.scatter(df['Soil_Moisture_%'], df['Plant_Height_cm'])

plt.title("Soil Moisture vs Plant Height")

plt.xlabel("Soil Moisture (%)")

plt.ylabel("Plant Height (cm)")

plt.show()

# %%
plt.figure(figsize=(7,5))

plt.scatter(df['Sunlight_hr'], df['Plant_Height_cm'])

plt.title("Sunlight vs Plant Height")

plt.xlabel("Sunlight (Hours)")

plt.ylabel("Plant Height (cm)")

plt.show()

# %%
plt.figure(figsize=(7,5))

plt.scatter(df['Fertilizer_g'], df['Plant_Height_cm'])

plt.title("Fertilizer vs Plant Height")

plt.xlabel("Fertilizer (g)")

plt.ylabel("Plant Height (cm)")

plt.show()

# %%
corr = df.corr(numeric_only=True)

corr
# Out:
#                      Days  Temperature_C  Humidity_%  Rainfall_mm  \
# Days             1.000000       0.009977   -0.065435     0.031160
# Temperature_C    0.009977       1.000000   -0.035297     0.030478
# Humidity_%      -0.065435      -0.035297    1.000000     0.010743
# Rainfall_mm      0.031160       0.030478    0.010743     1.000000
# Soil_Moisture_%  0.005169      -0.019444    0.003008    -0.102551
# Sunlight_hr     -0.009623      -0.002630    0.031454     0.028115
# Fertilizer_g    -0.072722      -0.032660   -0.000886    -0.039728
# Plant_Height_cm  0.988678       0.002384   -0.060247     0.047229
#
#                  Soil_Moisture_%  Sunlight_hr  Fertilizer_g  Plant_Height_cm
# Days                    0.005169    -0.009623     -0.072722         0.988678
# Temperature_C          -0.019444    -0.002630     -0.032660         0.002384
# Humidity_%              0.003008     0.031454     -0.000886        -0.060247
# ...

# %%
plt.figure(figsize=(10,8))

sns.heatmap(corr,
            annot=True,
            cmap='coolwarm',
            linewidths=0.5)

plt.title("Correlation Heatmap")

plt.show()

# %%
sns.pairplot(df)

plt.show()

# %%
plt.figure(figsize=(7,5))

sns.histplot(df['Plant_Height_cm'],
             kde=True)

plt.title("Plant Height Distribution")

plt.show()

# %%
plt.figure(figsize=(7,5))

sns.histplot(df['Rainfall_mm'],
             kde=True)

plt.title("Rainfall Distribution")

plt.show()

# %%
plt.figure(figsize=(15,8))

df.boxplot()

plt.xticks(rotation=45)

plt.title("Box Plot of All Features")

plt.show()

# %%
plt.figure(figsize=(6,5))

sns.boxplot(y=df['Temperature_C'])

plt.title("Temperature Outliers")

plt.show()

# %%
plt.figure(figsize=(6,5))

sns.boxplot(y=df['Humidity_%'])

plt.title("Humidity Outliers")

plt.show()

# %%
plt.figure(figsize=(6,5))

sns.boxplot(y=df['Rainfall_mm'])

plt.title("Rainfall Outliers")

plt.show()

# %%
plt.figure(figsize=(6,5))

sns.boxplot(y=df['Soil_Moisture_%'])

plt.title("Soil Moisture Outliers")

plt.show()

# %%
plt.figure(figsize=(6,5))

sns.boxplot(y=df['Sunlight_hr'])

plt.title("Sunlight Outliers")

plt.show()

# %%
plt.figure(figsize=(6,5))

sns.boxplot(y=df['Fertilizer_g'])

plt.title("Fertilizer Outliers")

plt.show()

# %%
# implementation
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression

from sklearn.tree import DecisionTreeRegressor

from sklearn.ensemble import RandomForestRegressor

from sklearn.svm import SVR

from sklearn.neighbors import KNeighborsRegressor

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
df = pd.read_csv("plant_dataset.csv")

# %%
X = df[['Days',
        'Temperature_C',
        'Humidity_%',
        'Rainfall_mm',
        'Soil_Moisture_%',
        'Sunlight_hr',
        'Fertilizer_g']]

y = df['Plant_Height_cm']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
lr = LinearRegression()

lr.fit(X_train, y_train)

lr_pred = lr.predict(X_test)

# %%
print("Linear Regression")

print("R2 Score :", r2_score(y_test, lr_pred))

print("MAE :", mean_absolute_error(y_test, lr_pred))

print("MSE :", mean_squared_error(y_test, lr_pred))
# Out:
# Linear Regression
# R2 Score : 0.9952826544400751
# MAE : 1.6069850145879934
# MSE : 3.2586900198412456

# %%
dt = DecisionTreeRegressor(random_state=42)

dt.fit(X_train, y_train)

dt_pred = dt.predict(X_test)

# %%
print("Decision Tree")

print("R2 Score :", r2_score(y_test, dt_pred))

print("MAE :", mean_absolute_error(y_test, dt_pred))

print("MSE :", mean_squared_error(y_test, dt_pred))
# Out:
# Decision Tree
# R2 Score : 0.9800973253819864
# MAE : 2.9448999999999987
# MSE : 13.74854699999999

# %%
rf = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

rf.fit(X_train, y_train)

rf_pred = rf.predict(X_test)

# %%
print("Random Forest")

print("R2 Score :", r2_score(y_test, rf_pred))

print("MAE :", mean_absolute_error(y_test, rf_pred))

print("MSE :", mean_squared_error(y_test, rf_pred))
# Out:
# Random Forest
# R2 Score : 0.9881832878575445
# MAE : 2.2574519999999993
# MSE : 8.162853756799976

# %%
from sklearn.preprocessing import StandardScaler

sc_X = StandardScaler()
sc_y = StandardScaler()

X_train_scaled = sc_X.fit_transform(X_train)
X_test_scaled = sc_X.transform(X_test)

y_train_scaled = sc_y.fit_transform(
    y_train.values.reshape(-1,1)
).ravel()

# %%
svr = SVR(kernel='rbf')

svr.fit(X_train_scaled, y_train_scaled)
# Out:
# SVR()

# %%
svr_pred = svr.predict(X_test_scaled)

svr_pred = sc_y.inverse_transform(
    svr_pred.reshape(-1,1)
)

# %%
print("SVR")

print("R2 Score :", r2_score(y_test, svr_pred))

print("MAE :", mean_absolute_error(y_test, svr_pred))

print("MSE :", mean_squared_error(y_test, svr_pred))
# Out:
# SVR
# R2 Score : 0.9756631499389802
# MAE : 3.256493204098372
# MSE : 16.811626242085364

# %%
knn = KNeighborsRegressor(
    n_neighbors=5
)

knn.fit(X_train, y_train)

knn_pred = knn.predict(X_test)

# %%
print("KNN")

print("R2 Score :", r2_score(y_test, knn_pred))

print("MAE :", mean_absolute_error(y_test, knn_pred))

print("MSE :", mean_squared_error(y_test, knn_pred))
# Out:
# KNN
# R2 Score : 0.982053391050019
# MAE : 2.7437799999999997
# MSE : 12.397318519999997

# %%
results = pd.DataFrame({

'Model':[
'Linear Regression',
'Decision Tree',
'Random Forest',
'SVR',
'KNN'
],

'R2 Score':[

r2_score(y_test,lr_pred),

r2_score(y_test,dt_pred),

r2_score(y_test,rf_pred),

r2_score(y_test,svr_pred),

r2_score(y_test,knn_pred)

],

'MAE':[

mean_absolute_error(y_test,lr_pred),

mean_absolute_error(y_test,dt_pred),

mean_absolute_error(y_test,rf_pred),

mean_absolute_error(y_test,svr_pred),

mean_absolute_error(y_test,knn_pred)

]

})

results
# Out:
#                Model  R2 Score       MAE
# 0  Linear Regression  0.995283  1.606985
# 1      Decision Tree  0.980097  2.944900
# 2      Random Forest  0.988183  2.257452
# 3                SVR  0.975663  3.256493
# 4                KNN  0.982053  2.743780

# %%
new_data = [[40,30,65,120,55,8,18]]

prediction = rf.predict(new_data)

print("Predicted Plant Height =", prediction[0], "cm")
# Out:
# Predicted Plant Height = 42.579499999999996 cm
# C:\Users\Janhavi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
import pickle

# %%
pickle.dump(rf, open("plant_growth_model.pkl", "wb"))

# %%
model = pickle.load(open("plant_growth_model.pkl", "rb"))
